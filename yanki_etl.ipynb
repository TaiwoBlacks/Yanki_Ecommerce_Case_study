# %%
# Importing necessary libraries
import numpy as npdf

# %%
import pandas as pd

# %%
yanki_df = pd.read_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/rawdata/yanki_ecommerce.csv')
yanki_df.head()
# Out:
#                                Order_ID                           Customer_ID  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2  e32af09a-b6ab-497e-af3a-331e4d4ed6e7  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 3  86eb8859-14ab-4d4e-9267-c5826f4e0c8e  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 4  7379b560-8897-4623-92a2-523ddcdc43a1  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
#
#       Customer_Name                            Product_ID Product_Name  \
# 0               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 1               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 2  Dominic Buchanan  2ef6e8fa-6a36-4515-b1c2-a0a700abf386      despite
# 3      Daniel Allen  3ba38e01-f8e7-4af2-9246-87ef0961d4f5          sea
# 4    Daniel Schmidt  a58c53bd-a34b-4541-b926-bec9eb84cac2     suddenly
#
# ...

# %%
yanki_df = pd.read_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/rawdata/yanki_ecommerce.csv')
yanki_df.head()
# Out:
#                                Order_ID                           Customer_ID  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2  e32af09a-b6ab-497e-af3a-331e4d4ed6e7  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 3  86eb8859-14ab-4d4e-9267-c5826f4e0c8e  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 4  7379b560-8897-4623-92a2-523ddcdc43a1  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
#
#       Customer_Name                            Product_ID Product_Name  \
# 0               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 1               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 2  Dominic Buchanan  2ef6e8fa-6a36-4515-b1c2-a0a700abf386      despite
# 3      Daniel Allen  3ba38e01-f8e7-4af2-9246-87ef0961d4f5          sea
# 4    Daniel Schmidt  a58c53bd-a34b-4541-b926-bec9eb84cac2     suddenly
#
# ...

# %%
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Customer_ID         1000 non-null   object
#  2   Customer_Name       1000 non-null   object
#  3   Product_ID          1020 non-null   object
#  4   Product_Name        1020 non-null   object
#  5   Brand               1020 non-null   object
#  6   Category            1020 non-null   object
#  7   Price               1020 non-null   float64
#  8   Quantity            1020 non-null   int64
#  9   Total_Price         1020 non-null   float64
#  10  Order_Date          1020 non-null   object
#  11  Shipping_Address    1020 non-null   object
#  12  City                1020 non-null   object
#  13  State               1019 non-null   object
#  14  Country             1020 non-null   object
# ...

# %%
yanki_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'Product_ID',
#        'Product_Name', 'Brand', 'Category', 'Price', 'Quantity', 'Total_Price',
#        'Order_Date', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code', 'Email', 'Phone_Number', 'Payment_Method',
#        'Transaction_Status'],
#       dtype='object')

# %%
yanki_df = pd.read_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/rawdata/yanki_ecommerce.csv')
yanki_df.head()
# Out:
#                                Order_ID                           Customer_ID  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2  e32af09a-b6ab-497e-af3a-331e4d4ed6e7  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 3  86eb8859-14ab-4d4e-9267-c5826f4e0c8e  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 4  7379b560-8897-4623-92a2-523ddcdc43a1  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
#
#       Customer_Name                            Product_ID Product_Name  \
# 0               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 1               NaN  64b689a8-bf03-47d2-a5cc-0723baeb1606        major
# 2  Dominic Buchanan  2ef6e8fa-6a36-4515-b1c2-a0a700abf386      despite
# 3      Daniel Allen  3ba38e01-f8e7-4af2-9246-87ef0961d4f5          sea
# 4    Daniel Schmidt  a58c53bd-a34b-4541-b926-bec9eb84cac2     suddenly
#
# ...

# %%
## DATA CLEANING AND MODELLING

# %%
## Drop missing values
yanki_df.dropna(subset=['Order_ID', 'Customer_ID'], inplace=True)
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Customer_ID         1000 non-null   object
#  2   Customer_Name       1000 non-null   object
#  3   Product_ID          1000 non-null   object
#  4   Product_Name        1000 non-null   object
#  5   Brand               1000 non-null   object
#  6   Category            1000 non-null   object
#  7   Price               1000 non-null   float64
#  8   Quantity            1000 non-null   int64
#  9   Total_Price         1000 non-null   float64
#  10  Order_Date          1000 non-null   object
#  11  Shipping_Address    1000 non-null   object
#  12  City                1000 non-null   object
#  13  State               999 non-null    object
#  14  Country             1000 non-null   object
# ...

# %%
# Convert 'Order_Date' to datetime format (handles day/month/year)
yanki_df['Order_Date'] = pd.to_datetime(yanki_df['Order_Date'], format='mixed', dayfirst=True)
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            1000 non-null   object
#  1   Customer_ID         1000 non-null   object
#  2   Customer_Name       1000 non-null   object
#  3   Product_ID          1000 non-null   object
#  4   Product_Name        1000 non-null   object
#  5   Brand               1000 non-null   object
#  6   Category            1000 non-null   object
#  7   Price               1000 non-null   float64
#  8   Quantity            1000 non-null   int64
#  9   Total_Price         1000 non-null   float64
#  10  Order_Date          1000 non-null   datetime64[ns]
#  11  Shipping_Address    1000 non-null   object
#  12  City                1000 non-null   object
#  13  State               999 non-null    object
#  14  Country             1000 non-null   object
# ...

# %%
## Drop missing values
yanki_df.dropna(subset=['State'], inplace=True)
yanki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 2 to 1019
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order_ID            999 non-null    object
#  1   Customer_ID         999 non-null    object
#  2   Customer_Name       999 non-null    object
#  3   Product_ID          999 non-null    object
#  4   Product_Name        999 non-null    object
#  5   Brand               999 non-null    object
#  6   Category            999 non-null    object
#  7   Price               999 non-null    float64
#  8   Quantity            999 non-null    int64
#  9   Total_Price         999 non-null    float64
#  10  Order_Date          999 non-null    datetime64[ns]
#  11  Shipping_Address    999 non-null    object
#  12  City                999 non-null    object
#  13  State               999 non-null    object
#  14  Country             999 non-null    object
# ...

# %%
yanki_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'Product_ID',
#        'Product_Name', 'Brand', 'Category', 'Price', 'Quantity', 'Total_Price',
#        'Order_Date', 'Shipping_Address', 'City', 'State', 'Country',
#        'Postal_Code', 'Email', 'Phone_Number', 'Payment_Method',
#        'Transaction_Status'],
#       dtype='object')

# %%
# Customer table
Customer_df = yanki_df[['Customer_ID', 'Customer_Name', 'Email', 'Phone_Number']].copy().drop_duplicates().reset_index(drop=True)
Customer_df.head()
# Out:
#                             Customer_ID     Customer_Name  \
# 0  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424  Dominic Buchanan
# 1  fa3ca35a-5540-404b-a7eb-9001cdcbd840      Daniel Allen
# 2  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34    Daniel Schmidt
# 3  4b9b409c-19f2-41c0-bc7c-6556e0647ebb     John Gonzalez
# 4  81b513ad-5c02-48cf-bff0-39e1440c4d22     Amber Benitez
#
#                     Email         Phone_Number
# 0  margaret97@example.com         259.603.6134
# 1    angela55@example.com  +1-869-659-4272x982
# 2     wayne59@example.org     292.840.0975x724
# 3    qsherman@example.com  +1-643-561-3912x262
# 4     derek85@example.com           3424148376

# %%
 # Products table
Products_df = yanki_df[['Product_ID',
       'Product_Name', 'Brand', 'Category', 'Price']].copy().drop_duplicates().reset_index(drop=True)
Products_df.head()
# Out:
#                              Product_ID Product_Name  \
# 0  2ef6e8fa-6a36-4515-b1c2-a0a700abf386      despite
# 1  3ba38e01-f8e7-4af2-9246-87ef0961d4f5          sea
# 2  a58c53bd-a34b-4541-b926-bec9eb84cac2     suddenly
# 3  e6021be5-90be-4199-b6c6-82542fb2973c         site
# 4  60127671-ab32-4fb5-bfeb-1a7782ad835e          act
#
#                           Brand     Category   Price
# 0      Lawson, Stone and Campos  perfume oil  250.57
# 1              Washington Group  perfume oil  179.81
# 2                   Rodgers Ltd  perfume oil  600.55
# 3     Wilson, Scott and Johnson  perfume oil  414.36
# 4  Riddle, Alvarez and Robinson      perfume  704.05

# %%
# Payment_Method table
Payment_Method_df = yanki_df[['Order_ID', 'Payment_Method', 'Transaction_Status']].copy().drop_duplicates().reset_index(drop=True)
Payment_Method_df.head()
# Out:
#                                Order_ID Payment_Method Transaction_Status
# 0  e32af09a-b6ab-497e-af3a-331e4d4ed6e7     Debit Card          completed
# 1  86eb8859-14ab-4d4e-9267-c5826f4e0c8e    Credit Card          completed
# 2  7379b560-8897-4623-92a2-523ddcdc43a1         PayPal            pending
# 3  30c57f86-2fed-43c0-a399-654c2c3bb18d         PayPal          completed
# 4  41c29d81-9622-43c1-b537-7cdb320d3e6a         PayPal            pending

# %%
# Shipping_Address table
Shipping_Address_df = yanki_df[['Customer_ID', 'Shipping_Address', 'City', 'State', 'Country', 'Postal_Code']].copy().drop_duplicates().reset_index(drop=True)
Payment_Method_df.head()

Shipping_Address_df.index.name = 'Shipping_ID'
Shipping_Address_df = Shipping_Address_df.reset_index()
Shipping_Address_df.head()
# Out:
#    Shipping_ID                           Customer_ID  \
# 0            0  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 1            1  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 2            2  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
# 3            3  4b9b409c-19f2-41c0-bc7c-6556e0647ebb
# 4            4  81b513ad-5c02-48cf-bff0-39e1440c4d22
#
#                                   Shipping_Address           City  \
# 0                 PSC 2224, Box 2284\nAPO AP 65880  Jordanborough
# 1           83909 Johnson Mall\nTranberg, MS 99017  Lake Ginatown
# 2          82101 Johnson Flat\nWest Ryan, MS 29075     Sarahville
# 3        4542 Gary Lane\nSouth Alexander, VI 27671  Lake Michelle
# 4  6794 Caroline Crescent\nEast Karlside, GU 81379     Olsenville
#
#          State                           Country  Postal_Code
# 0     Arkansas                            Kuwait        27879
# 1      Georgia  Saint Vincent and the Grenadines        39336
# ...

# %%
# Orders table
Orders_df = yanki_df[['Order_ID', 'Customer_ID', 'Product_ID', 'Quantity', 
                     'Total_Price', 'Order_Date']].copy().drop_duplicates().reset_index(drop=True)
Orders_df.head()
# Out:
#                                Order_ID                           Customer_ID  \
# 0  e32af09a-b6ab-497e-af3a-331e4d4ed6e7  e0d6cb3c-c4b0-4cfe-8225-b65d094d2424
# 1  86eb8859-14ab-4d4e-9267-c5826f4e0c8e  fa3ca35a-5540-404b-a7eb-9001cdcbd840
# 2  7379b560-8897-4623-92a2-523ddcdc43a1  7ad4de53-e6d7-4cd3-99b8-13fb70fe7a34
# 3  30c57f86-2fed-43c0-a399-654c2c3bb18d  4b9b409c-19f2-41c0-bc7c-6556e0647ebb
# 4  41c29d81-9622-43c1-b537-7cdb320d3e6a  81b513ad-5c02-48cf-bff0-39e1440c4d22
#
#                              Product_ID  Quantity  Total_Price  \
# 0  2ef6e8fa-6a36-4515-b1c2-a0a700abf386         2       501.14
# 1  3ba38e01-f8e7-4af2-9246-87ef0961d4f5         6      1078.86
# 2  a58c53bd-a34b-4541-b926-bec9eb84cac2         7      4203.85
# 3  e6021be5-90be-4199-b6c6-82542fb2973c         9      3729.24
# 4  60127671-ab32-4fb5-bfeb-1a7782ad835e         9      6336.45
#
#            Order_Date
# 0 2020-03-06 06:49:00
# 1 2020-07-31 07:09:00
# 2 2021-05-11 04:33:00
# 3 2023-09-12 01:47:00
# ...

# %%
import os

## Ensure the directory exists
os.makedirs('Yanki-Ecommerce-Case-study/Dataset/cleandata', exist_ok=True)

## Saving the tables as CSV files
Customer_df.to_csv(r'Yanki-Ecommerce-Case-study/Dataset/cleandata/Customers.csv', index=False)

# %%
## Saving the tables as CSV files
Customer_df.to_csv(r'Yanki-Ecommerce-Case-study/Dataset/cleandata/Customers.csv', index=False)

# %%
Products_df.to_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Products.csv', index=False)
Orders_df.to_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Orders.csv', index=False)
Shipping_Address_df.to_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Shipping_Address.csv', index=False)
Payment_Method_df.to_csv('/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Payment_Method.csv', index=False)

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
# Connect PgAdmin4 server

def get_db_connection():
    connection = psycopg2.connect(
        host = 'localhost',
        database = 'yanki_ecommerce',
        user = 'postgres',
        password = '#Adejoke8509'
    )
    return connection

# %%
conn = get_db_connection()

# %%
## Create SQL tables
def create_tables():
    conn = get_db_connection()
    cursor = conn.cursor()
    
    create_table_query = '''
                            CREATE SCHEMA IF NOT EXISTS yanki;

                            DROP TABLE IF EXISTS yanki.payment_method CASCADE;
                            DROP TABLE IF EXISTS yanki.shipping_address CASCADE;
                            DROP TABLE IF EXISTS yanki.orders CASCADE;
                            DROP TABLE IF EXISTS yanki.products CASCADE;
                            DROP TABLE IF EXISTS yanki.customers CASCADE;

                            CREATE TABLE IF NOT EXISTS yanki.customers (
                                Customer_ID UUID PRIMARY KEY,
                                Customer_Name TEXT,
                                Email TEXT,
                                Phone_Number TEXT
                            );

                            CREATE TABLE IF NOT EXISTS yanki.products (
                                Product_ID UUID PRIMARY KEY,
                                Product_Name TEXT,
                                Brand TEXT,
                                Category TEXT,
                                Price FLOAT
                            );

                            CREATE TABLE IF NOT EXISTS yanki.orders (
                                Order_ID UUID PRIMARY KEY,
                                Customer_ID UUID REFERENCES yanki.customers(Customer_ID),
                                Product_ID UUID REFERENCES yanki.products(Product_ID),
                                Quantity INT,
                                Total_Price FLOAT,
                                Order_Date TIMESTAMP
                            );

                            CREATE TABLE IF NOT EXISTS yanki.shipping_address (
                                Shipping_ID SERIAL PRIMARY KEY,
                                Customer_ID UUID REFERENCES yanki.customers(Customer_ID),
                                Shipping_Address TEXT,
                                City TEXT,
                                State TEXT,
                                Country TEXT,
                                Postal_Code TEXT
                            );

                            CREATE TABLE IF NOT EXISTS yanki.payment_method (
                                Order_ID UUID PRIMARY KEY REFERENCES yanki.orders(Order_ID),
                                Payment_Method TEXT,
                                Transaction_Status TEXT
                            );'''
    
    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

# %%
create_tables()

# %%
display(Orders_df.columns)
display(Orders_df.info())
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Quantity', 'Total_Price',
#        'Order_Date'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     989 non-null    object
#  1   Customer_ID  989 non-null    object
#  2   Product_ID   989 non-null    object
#  3   Quantity     989 non-null    int64
#  4   Total_Price  989 non-null    float64
#  5   Order_Date   989 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 46.5+ KB
# None

# %%
display(Products_df.columns)
display(Products_df.info())
# Out:
# Index(['Product_ID', 'Product_Name', 'Brand', 'Category', 'Price'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    989 non-null    object
#  1   Product_Name  989 non-null    object
#  2   Brand         989 non-null    object
#  3   Category      989 non-null    object
#  4   Price         989 non-null    float64
# dtypes: float64(1), object(4)
# memory usage: 38.8+ KB
# None

# %%
display(Customer_df.columns)
display(Customer_df.info())
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Email', 'Phone_Number'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    989 non-null    object
#  1   Customer_Name  989 non-null    object
#  2   Email          989 non-null    object
#  3   Phone_Number   989 non-null    object
# dtypes: object(4)
# memory usage: 31.0+ KB
# None

# %%
import csv
def load_data_from_csv(csv_path):
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''  
                           INSERT INTO yanki.customers (Customer_ID, Customer_Name, Email, Phone_Number)
                           VALUES (%s, %s, %s, %s); ''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Customers.csv'

load_data_from_csv(csv_file_path)

# %%
Customer_df.columns
# Out:
# Index(['Customer_ID', 'Customer_Name', 'Email', 'Phone_Number'], dtype='object')

# %%
import csv
def load_data_from_csv(csv_path):
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''  
                           INSERT INTO yanki.products (Product_ID, Product_Name, Brand, Category, Price)
                           VALUES (%s, %s, %s, %s, %s); ''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Products.csv'

load_data_from_csv(csv_file_path)

# %%
Products_df.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Brand', 'Category', 'Price'], dtype='object')

# %%
import csv
def load_data_from_csv(csv_path):
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''  
                           INSERT INTO yanki.orders (Order_ID, Customer_ID, Product_ID, Quantity, Total_Price, Order_Date)
                           VALUES (%s, %s, %s, %s, %s, %s); ''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Orders.csv'

load_data_from_csv(csv_file_path)

# %%
Orders_df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Quantity', 'Total_Price',
#        'Order_Date'],
#       dtype='object')

# %%
import csv
def load_data_from_csv(csv_path):
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''  
                           INSERT INTO yanki.shipping_address (Shipping_ID, Customer_ID, Shipping_Address, City, State, Country, Postal_Code)
                           VALUES (%s, %s, %s, %s, %s, %s, %s); ''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Shipping_Address.csv'

load_data_from_csv(csv_file_path)

# %%
Shipping_Address_df.columns
# Out:
# Index(['Shipping_ID', 'Customer_ID', 'Shipping_Address', 'City', 'State',
#        'Country', 'Postal_Code'],
#       dtype='object')

# %%
Payment_Method_df.columns
# Out:
# Index(['Order_ID', 'Payment_Method', 'Transaction_Status'], dtype='object')

# %%
import csv
def load_data_from_csv(csv_path):
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r') as file:
        reader = csv.reader(file)
        next(reader)
        for row in reader:
            cursor.execute('''  
                           INSERT INTO yanki.payment_method (Order_ID, Payment_Method, Transaction_Status)
                           VALUES (%s, %s, %s); ''',
                           row
                        )
    conn.commit()
    cursor.close()
    conn.close()
    
csv_file_path = r'/Users/taiwoblackson/Desktop/Yanki Ecommerce Case Study/Yanki-Ecommerce-Case-study/Dataset/cleandata/Payment_Method.csv'

load_data_from_csv(csv_file_path)
